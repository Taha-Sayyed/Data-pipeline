# %%
pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.5/11.5 MB 6.4 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.9/20.9 MB 4.8 MB/s eta 0:00:0000:0100:01
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
data=sp.playlist_tracks(playlist_URI)

# %%
#Album Data
data['items'][0] #First Album Information
print(len(data['items']))
#print(data['items'][0])
# Out:
# 100

# %%
data['items'][0]['track']['album']  #accesses the album information of the first track.
# Out:
# {'available_markets': ['AR',
#   'AU',
#   'AT',
#   'BE',
#   'BO',
#   'BR',
#   'BG',
#   'CA',
#   'CL',
#   'CO',
#   'CR',
#   'CY',
#   'CZ',
#   'DK',
#   'DO',
#   'DE',
#   'EC',
#   'EE',
#   'SV',
#   'FI',
#   'FR',
#   'GR',
#   'GT',
#   'HN',
#   'HK',
#   'HU',
#   'IS',
#   'IE',
#   'IT',
#   'LV',
#   'LT',
#   'LU',
#   'MY',
#   'MT',
#   'MX',
#   'NL',
#   'NZ',
#   'NI',
#   'NO',
#   'PA',
#   'PY',
#   'PE',
#   'PH',
#   'PL',
#   'PT',
#   'SG',
#   'SK',
#   'ES',
#   'SE',
#   'CH',
#   'TW',
#   'TR',
#   'UY',
#   'US',
#   'GB',
#   'AD',
#   'LI',
#   'MC',
#   'ID',
#   'JP',
#   'TH',
#   'VN',
#   'RO',
#   'IL',
#   'ZA',
#   'SA',
#   'AE',
#   'BH',
#   'QA',
#   'OM',
#   'KW',
#   'EG',
#   'MA',
#   'DZ',
#   'TN',
#   'LB',
#   'JO',
#   'PS',
#   'IN',
#   'KZ',
#   'MD',
#   'UA',
#   'AL',
#   'BA',
#   'HR',
#   'ME',
#   'MK',
#   'RS',
#   'SI',
#   'KR',
#   'BD',
#   'PK',
#   'LK',
#   'GH',
#   'KE',
#   'NG',
#   'TZ',
# ...

# %%
album_list=[]
for row in data['items']:
    album_id=row['track']['album']['id']
    album_name=row['track']['album']['name']
    album_release_date=row['track']['album']['release_date']
    album_total_tracks=row['track']['album']['total_tracks']
    album_url=row['track']['album']['external_urls']
    album_element={'album_id':album_id,'name':album_name,'release_date':album_release_date,'total_tracks':album_total_tracks,'url':album_total_tracks}
    album_list.append(album_element)

# %%
print(album_list)
# Out:
# [{'album_id': '12sC6UjMWz6EaxnzyfCNMe', 'name': 'Bhediya (Original Motion Picture Soundtrack)', 'release_date': '2022-11-22', 'total_tracks': 6, 'url': 6}, {'album_id': '7BpW3kwzoeLX4RFWJVvjGx', 'name': 'Zamaana Lage (From "Metro ... In Dino")', 'release_date': '2025-05-28', 'total_tracks': 1, 'url': 1}, {'album_id': '3I8PdIhk6pNm8Kv0HiF14V', 'name': 'Tujhe Kitna Chahne Lage (From "Kabir Singh")', 'release_date': '2019-05-31', 'total_tracks': 1, 'url': 1}, {'album_id': '5mZX4EMwEyohNmVfLTDtXn', 'name': 'Satranga (From "ANIMAL")', 'release_date': '2023-10-27', 'total_tracks': 1, 'url': 1}, {'album_id': '3SMzRnmBPXz1ujZrZV8vwq', 'name': 'Dil Ka Kya (From "Metro ... In Dino")', 'release_date': '2025-06-09', 'total_tracks': 1, 'url': 1}, {'album_id': '0Rkv5iqjF2uenfL0OVB8hg', 'name': 'Aashiqui 2', 'release_date': '2013-04-06', 'total_tracks': 12, 'url': 12}, {'album_id': '3RtFFza4brQXoNSv19g1ps', 'name': 'Genius (Original Motion Picture Soundtrack)', 'release_date': '2018-08-24', 'total_
# ...

# %%
artist_list=[]
for row in data['items']:
    for key,value in row.items():
        if key=="track":
            for artist in value['artists']:
                artist_dict={'artist_id':artist['id'],'artist_name':artist['name'],'url':artist['href']}
                artist_list.append(artist_dict)

# %%
artist_list
# Out:
# [{'artist_id': '1mBydYMVBECdDmMfE2sEUO',
#   'artist_name': 'Sachin-Jigar',
#   'url': 'https://api.spotify.com/v1/artists/1mBydYMVBECdDmMfE2sEUO'},
#  {'artist_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artist_name': 'Arijit Singh',
#   'url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'},
#  {'artist_id': '2fMqTqiTxUDlmcOEPaQSsx',
#   'artist_name': 'Amitabh Bhattacharya',
#   'url': 'https://api.spotify.com/v1/artists/2fMqTqiTxUDlmcOEPaQSsx'},
#  {'artist_id': '1wRPtKGflJrBx9BmLsSwlU',
#   'artist_name': 'Pritam',
#   'url': 'https://api.spotify.com/v1/artists/1wRPtKGflJrBx9BmLsSwlU'},
#  {'artist_id': '4YRxDV8wJFPHPTeXepOstw',
#   'artist_name': 'Arijit Singh',
#   'url': 'https://api.spotify.com/v1/artists/4YRxDV8wJFPHPTeXepOstw'},
#  {'artist_id': '6iv4lysB1yHXoZJ2gfqTdh',
#   'artist_name': 'Shashwat Singh',
#   'url': 'https://api.spotify.com/v1/artists/6iv4lysB1yHXoZJ2gfqTdh'},
#  {'artist_id': '5SMMGwEnXqIWXvhfBfV6BD',
#   'artist_name': 'Qaisar-Ul-Jafri',
# ...

# %%
song_list = []
for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
song_list
# Out:
# [{'song_id': '5bQ6oDLqvw8tywmnSmwEyL',
#   'song_name': 'Apna Bana Le',
#   'duration_ms': 261702,
#   'url': 'https://open.spotify.com/track/5bQ6oDLqvw8tywmnSmwEyL',
#   'popularity': 78,
#   'song_added': '2023-11-10T23:20:33Z',
#   'album_id': '12sC6UjMWz6EaxnzyfCNMe',
#   'artist_id': '1mBydYMVBECdDmMfE2sEUO'},
#  {'song_id': '76ec1a1bkFfOqoVf6e7nae',
#   'song_name': 'Zamaana Lage (From "Metro ... In Dino")',
#   'duration_ms': 196138,
#   'url': 'https://open.spotify.com/track/76ec1a1bkFfOqoVf6e7nae',
#   'popularity': 75,
#   'song_added': '2025-05-28T14:07:00Z',
#   'album_id': '7BpW3kwzoeLX4RFWJVvjGx',
#   'artist_id': '1wRPtKGflJrBx9BmLsSwlU'},
#  {'song_id': '2Fv2injs4qAm8mJBGaxVKU',
#   'song_name': 'Tujhe Kitna Chahne Lage (From "Kabir Singh")',
#   'duration_ms': 284779,
#   'url': 'https://open.spotify.com/track/2Fv2injs4qAm8mJBGaxVKU',
#   'popularity': 82,
#   'song_added': '2023-10-25T09:02:53Z',
#   'album_id': '3I8PdIhk6pNm8Kv0HiF14V',
# ...

# %%
album_df = pd.DataFrame.from_dict(album_list)
album_df['url'] = album_df['url'].astype(str)

# %%
album_df
# Out:
#                   album_id                                               name  \
# 0   12sC6UjMWz6EaxnzyfCNMe       Bhediya (Original Motion Picture Soundtrack)
# 1   7BpW3kwzoeLX4RFWJVvjGx            Zamaana Lage (From "Metro ... In Dino")
# 2   3I8PdIhk6pNm8Kv0HiF14V       Tujhe Kitna Chahne Lage (From "Kabir Singh")
# 3   5mZX4EMwEyohNmVfLTDtXn                           Satranga (From "ANIMAL")
# 4   3SMzRnmBPXz1ujZrZV8vwq              Dil Ka Kya (From "Metro ... In Dino")
# ..                     ...                                                ...
# 95  2Lxoc72vRTGdQfMvj7Ovi1                            Yeh Jawaani Hai Deewani
# 96  5SipVGOTd69oEJb3W84HYd  Chal Ghar Chalen (From "Malang - Unleash The M...
# 97  71whGqTrr3pCoiAsZx0SAe                                           Intezaar
# 98  3Ptq3ARmJ8iTLBb7M7Bho0                        Pachtaoge (From "Jaani Ve")
# 99  0Rkv5iqjF2uenfL0OVB8hg                                         Aashiqui 2
#
# ...

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      100 non-null    object
#  1   name          100 non-null    object
#  2   release_date  100 non-null    object
#  3   total_tracks  100 non-null    int64
#  4   url           100 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 4.0+ KB

# %%
album_df = album_df.drop_duplicates(subset=['album_id'])

# %%
album_df
# Out:
#                   album_id                                               name  \
# 0   12sC6UjMWz6EaxnzyfCNMe       Bhediya (Original Motion Picture Soundtrack)
# 1   7BpW3kwzoeLX4RFWJVvjGx            Zamaana Lage (From "Metro ... In Dino")
# 2   3I8PdIhk6pNm8Kv0HiF14V       Tujhe Kitna Chahne Lage (From "Kabir Singh")
# 3   5mZX4EMwEyohNmVfLTDtXn                           Satranga (From "ANIMAL")
# 4   3SMzRnmBPXz1ujZrZV8vwq              Dil Ka Kya (From "Metro ... In Dino")
# ..                     ...                                                ...
# 94  1cttjZoENYipDCPgISthpY  Pyaar Hota Kayi Baar Hai (From "Tu Jhoothi Mai...
# 95  2Lxoc72vRTGdQfMvj7Ovi1                            Yeh Jawaani Hai Deewani
# 96  5SipVGOTd69oEJb3W84HYd  Chal Ghar Chalen (From "Malang - Unleash The M...
# 97  71whGqTrr3pCoiAsZx0SAe                                           Intezaar
# 98  3Ptq3ARmJ8iTLBb7M7Bho0                        Pachtaoge (From "Jaani Ve")
#
# ...

# %%
artist_df = pd.DataFrame.from_dict(artist_list)

# %%
artist_df = artist_df.drop_duplicates(subset=['artist_id'])

# %%
#Song Dataframe
song_df=pd.DataFrame.from_dict(song_list)

# %%
song_df.head()
# Out:
#                   song_id                                     song_name  \
# 0  5bQ6oDLqvw8tywmnSmwEyL                                  Apna Bana Le
# 1  76ec1a1bkFfOqoVf6e7nae       Zamaana Lage (From "Metro ... In Dino")
# 2  2Fv2injs4qAm8mJBGaxVKU  Tujhe Kitna Chahne Lage (From "Kabir Singh")
# 3  3yHyiUDJdz02FZ6jfUbsmY                      Satranga (From "ANIMAL")
# 4  69tPsAXkjn3cTXoLSMr6d3         Dil Ka Kya (From "Metro ... In Dino")
#
#    duration_ms                                                url  popularity  \
# 0       261702  https://open.spotify.com/track/5bQ6oDLqvw8tywm...          78
# 1       196138  https://open.spotify.com/track/76ec1a1bkFfOqoV...          75
# 2       284779  https://open.spotify.com/track/2Fv2injs4qAm8mJ...          82
# 3       271169  https://open.spotify.com/track/3yHyiUDJdz02FZ6...          81
# 4       360063  https://open.spotify.com/track/69tPsAXkjn3cTXo...           0
#
# ...

# %%
artist_df.head()
# Out:
#                 artist_id           artist_name  \
# 0  1mBydYMVBECdDmMfE2sEUO          Sachin-Jigar
# 1  4YRxDV8wJFPHPTeXepOstw          Arijit Singh
# 2  2fMqTqiTxUDlmcOEPaQSsx  Amitabh Bhattacharya
# 3  1wRPtKGflJrBx9BmLsSwlU                Pritam
# 5  6iv4lysB1yHXoZJ2gfqTdh        Shashwat Singh
#
#                                                  url
# 0  https://api.spotify.com/v1/artists/1mBydYMVBEC...
# 1  https://api.spotify.com/v1/artists/4YRxDV8wJFP...
# 2  https://api.spotify.com/v1/artists/2fMqTqiTxUD...
# 3  https://api.spotify.com/v1/artists/1wRPtKGflJr...
# 5  https://api.spotify.com/v1/artists/6iv4lysB1yH...

# %%
album_df.head()
# Out:
#                  album_id                                          name  \
# 0  12sC6UjMWz6EaxnzyfCNMe  Bhediya (Original Motion Picture Soundtrack)
# 1  7BpW3kwzoeLX4RFWJVvjGx       Zamaana Lage (From "Metro ... In Dino")
# 2  3I8PdIhk6pNm8Kv0HiF14V  Tujhe Kitna Chahne Lage (From "Kabir Singh")
# 3  5mZX4EMwEyohNmVfLTDtXn                      Satranga (From "ANIMAL")
# 4  3SMzRnmBPXz1ujZrZV8vwq         Dil Ka Kya (From "Metro ... In Dino")
#
#   release_date  total_tracks url
# 0   2022-11-22             6   6
# 1   2025-05-28             1   1
# 2   2019-05-31             1   1
# 3   2023-10-27             1   1
# 4   2025-06-09             1   1

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 86 entries, 0 to 98
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      86 non-null     object
#  1   name          86 non-null     object
#  2   release_date  86 non-null     object
#  3   total_tracks  86 non-null     int64
#  4   url           86 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 4.0+ KB

# %%
artist_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 96 entries, 0 to 262
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   artist_id    96 non-null     object
#  1   artist_name  96 non-null     object
#  2   url          96 non-null     object
# dtypes: object(3)
# memory usage: 3.0+ KB

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      100 non-null    object
#  1   song_name    100 non-null    object
#  2   duration_ms  100 non-null    int64
#  3   url          100 non-null    object
#  4   popularity   100 non-null    int64
#  5   song_added   100 non-null    object
#  6   album_id     100 non-null    object
#  7   artist_id    100 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 6.4+ KB

# %%
song_df['song_added']=pd.to_datetime(song_df['song_added'])

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      100 non-null    object
#  1   song_name    100 non-null    object
#  2   duration_ms  100 non-null    int64
#  3   url          100 non-null    object
#  4   popularity   100 non-null    int64
#  5   song_added   100 non-null    datetime64[ns, UTC]
#  6   album_id     100 non-null    object
#  7   artist_id    100 non-null    object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 6.4+ KB

# %%
# import json
# import os
# import spotipy
# from spotipy.oauth2 import SpotifyClientCredentials


# def lambda_handler(event, context):
    
#     client_id = os.environ.get('client_id')
#     client_secret = os.environ.get('client_secret')

    # client_credential_manager=SpotifyClientCredentials(client_id=client_id,client_secret=client_secret)
    # sp=spotipy.Spotify(client_credentials_manager=client_credential_manager)
    # playlists=sp.user_playlists('spotify')

    # playlist_link="https://open.spotify.com/playlist/7qxn6GsFH77ghVtKzOnAYA"
    # playlist_URI=playlist_link.split("/")[-1].split("?")[0]

    # spotify_data = sp.playlist_tracks(playlist_URI)
    # print(spotify_data)

# %%
album_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 86 entries, 0 to 98
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   album_id      86 non-null     object
#  1   name          86 non-null     object
#  2   release_date  86 non-null     object
#  3   total_tracks  86 non-null     int64
#  4   url           86 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 4.0+ KB

# %%
song_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   song_id      100 non-null    object
#  1   song_name    100 non-null    object
#  2   duration_ms  100 non-null    int64
#  3   url          100 non-null    object
#  4   popularity   100 non-null    int64
#  5   song_added   100 non-null    datetime64[ns, UTC]
#  6   album_id     100 non-null    object
#  7   artist_id    100 non-null    object
# dtypes: datetime64[ns, UTC](1), int64(2), object(5)
# memory usage: 6.4+ KB
